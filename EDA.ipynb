# %% [markdown]
# # **EDA 1**
# # **About Dataset**
# # Source:
#
# The dataset is available on Kaggle, simulating data commonly observed in real-world online bike resale platforms.
#
# # Description:
#
# The dataset comprises 1061 records of used bike listings. These records include details about the bike's brand and model, selling price, kilometers driven, ownership history, and other attributes. It is particularly useful for resale value prediction, market analysis, and understanding buyer preferences. The dataset consists of 7 features, combining both numeric and categorical data, offering a comprehensive view of the second-hand bike market.
#
# # **Title: Bike Details Dataset**
#
# **=name:** Brand and model name of the bike (Categorical, e.g., "Royal Enfield Classic 350", "Honda Dio")
#
# **selling_price:**Listed selling price in INR (Numeric, e.g., 175000, 45000)
#
# **year:** Manufacturing year of the bike (Numeric, e.g., 2019, 2015)
#
# **seller_type:** Seller category, either "Individual" or "Dealer" (Categorical)
#
# **owner:** Ownership history, e.g., "1st owner", "2nd owner
#
# **km_driven:** Total kilometers driven (Numeric, in km, e.g., 12000, 23000)
#
# **ex_showroom_price:** Original showroom price in INR (Numeric, e.g., 148114.0, 89643.0, etc,.).
#
# # **Questions**

# %%
#Q1. What is the range of selling prices in the dataset

import pandas as pd

# Use the correct file name from the uploaded list
file_path = "/content/BIKE DETAILS (1).csv"

try:
    df = pd.read_csv(file_path)
    print("Dataset loaded successfully!")
    print(df.head())  # Display first few rows

    # Find the range of selling prices
    min_price = df["selling_price"].min()
    max_price = df["selling_price"].max()
    print(f"Range of selling prices: ₹{min_price} to ₹{max_price}")
except Exception as e:
    print("Error:", e)
# Out:
# Error: [Errno 2] No such file or directory: '/content/BIKE DETAILS (1).csv'

# %% [markdown]
# Q2. What is the median selling price for bikes in the dataset?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Calculate median selling price
median_price = df["selling_price"].median()
print(f"Median selling price: ₹{median_price}")

# %% [markdown]
# Q3. What is the most common seller type

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Count occurrences of each seller type
seller_counts = df["seller_type"].value_counts()
print(seller_counts)

# %% [markdown]
# Q4. How many bikes have driven more than 50,000 kilometers?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Count bikes with km_driven > 50,000
high_mileage_bikes = df[df["km_driven"] > 50000]
print(f"Number of bikes driven more than 50,000 km: {len(high_mileage_bikes)}")

# %% [markdown]
# Q5. What is the average km_driven value for each ownership type?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Calculate average km_driven for each ownership type
avg_km_driven = df.groupby("owner")["km_driven"].mean()
print(avg_km_driven)

# %% [markdown]
# Q6. What proportion of bikes are from the year 2015 or older?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Count bikes from 2015 or older
older_bikes = df[df["year"] <= 2015]
proportion = len(older_bikes) / len(df) * 100

print(f"Proportion of bikes from 2015 or older: {proportion:.2f}%")

# %% [markdown]
# Q7. What is the trend of missing values across the dataset?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Check missing values
missing_values = df.isnull().sum()
print("Missing Values Count:\n", missing_values)

# Visualizing missing values
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.heatmap(df.isnull(), cbar=False, cmap="coolwarm")
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# Q8. What is the highest ex_showroom_price recorded, and for which bike?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Find the highest ex-showroom price and corresponding bike
max_price = df["ex_showroom_price"].max()
bike_name = df[df["ex_showroom_price"] == max_price]["name"].values[0]

print(f"Highest ex-showroom price: ₹{max_price}, Bike: {bike_name}")

# %% [markdown]
# Q9. What is the total number of bikes listed by each seller type?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Count occurrences of each seller type
seller_counts = df["seller_type"].value_counts()
print(seller_counts)

# %% [markdown]
# Q10. What is the relationship between selling_price and km_driven for first-owner bikes?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Filter first-owner bikes
first_owner_bikes = df[df["owner"] == "1st owner"]

# Scatter plot to visualize relationship
plt.figure(figsize=(8, 5))
sns.scatterplot(x=first_owner_bikes["km_driven"], y=first_owner_bikes["selling_price"], alpha=0.6)
plt.xlabel("Kilometers Driven")
plt.ylabel("Selling Price")
plt.title("Selling Price vs. Kilometers Driven for First-Owner Bikes")
plt.show()

# Calculate correlation coefficient
correlation = first_owner_bikes["km_driven"].corr(first_owner_bikes["selling_price"])
print(f"Correlation between selling price and km driven: {correlation:.2f}")

# %% [markdown]
# Q11. Identify and remove outliers in the km_driven column using the IQR method?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Calculate Q1, Q3, and IQR
Q1 = df["km_driven"].quantile(0.25)
Q3 = df["km_driven"].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"IQR: {IQR}, Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")

# Remove outliers
df_cleaned = df[(df["km_driven"] >= lower_bound) & (df["km_driven"] <= upper_bound)]

print(f"Original dataset size: {len(df)}, Cleaned dataset size: {len(df_cleaned)}")

# %% [markdown]
# Q12. Perform a bivariate analysis to visualize the relationship between year and selling_price?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Scatter plot to visualize the trend
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["year"], y=df["selling_price"], alpha=0.6)
plt.xlabel("Manufacturing Year")
plt.ylabel("Selling Price (₹)")
plt.title("Selling Price vs. Year of Manufacture")
plt.show()

# Box plot to observe price distribution per year
plt.figure(figsize=(10, 5))
sns.boxplot(x=df["year"], y=df["selling_price"])
plt.xticks(rotation=45)
plt.xlabel("Manufacturing Year")
plt.ylabel("Selling Price (₹)")
plt.title("Distribution of Selling Price Across Years")
plt.show()

# %% [markdown]
# Q13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Calculate bike age (assuming current year is 2025)
df["bike_age"] = 2025 - df["year"]

# Avoid division by zero (for brand-new bikes)
df = df[df["bike_age"] > 0]

# Calculate depreciation per year
df["depreciation_per_year"] = df["selling_price"] / df["bike_age"]

# Find the average depreciation
average_depreciation = df["depreciation_per_year"].mean()

print(f"Average depreciation in selling price per year: ₹{average_depreciation:.2f}")

# %% [markdown]
# Q14. Which bike names are priced significantly above the average price for their manufacturing year?

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Calculate average selling price per year
avg_price_per_year = df.groupby("year")["selling_price"].mean()

# Merge this average price back into the dataset
df["avg_price_for_year"] = df["year"].map(avg_price_per_year)

# Identify bikes priced significantly above the average (e.g., 1.5 times higher)
df_high_price = df[df["selling_price"] > 1.5 * df["avg_price_for_year"]]

# Display results
print(df_high_price[["name", "year", "selling_price", "avg_price_for_year"]])

# %% [markdown]
# Q15. Develop a correlation matrix for numeric columns and visualize it using a heatmap.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/content/BIKE DETAILS (1).csv")  # Ensure correct file path

# Select only numeric columns
numeric_df = df.select_dtypes(include=["number"])

# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix for Numeric Columns")
plt.show()

# %% [markdown]
# # **EDA 2:**

# %% [markdown]
# **Souece:**
#
# The dataset is available on Kaggle, representing data commonly seen in online car resale platforms.

# %% [markdown]
# **Description:**
#
# The dataset contains details about used cars listed for sale, such as brand, model, selling price, kilometers driven, fuel type, and transmission type. This information is valuable for predictive modeling, market analysis, and understanding customer preferences

# %% [markdown]
# # **Title : Car sale Datset**

# %% [markdown]
# **Features:**

# %% [markdown]
# **Car_id**: A unique identifier for each car in the dataset, helping to track individual car entries
#
# **Date**: The date when the car sale transaction took place, formatted as YYYY-MM-DD
#
# **Customer Name**: The name of the customer who purchased the car, represented as a string
#
# **Gender**: The gender of the customer, categorized as "Male" or "Female.
#
# **Annual Income**: The customer's annual income in US dollars, represented as a numeric value
#
# **Dealer_Name**: The name of the dealership selling the car, represented as a string
#
# **Company**: The manufacturer or brand name of the car, such as "Toyota," "Ford," etc
#
# **Model**: The specific model name of the car, such as "Corolla," "C
#
# **Engine**: The engine type of the car, such as "V6," "I4," etc
#
# **Transmission**: The type of transmission in the car, either "Manual" or "Automatic.
#
# **Color**: The color of the car, represented as a string (e.g., "Red," "Blue") bold text Price ($): The selling price of the car in US dollars Body
#
# **Dealer_No**: A unique identifier for each car dealer in the dataset
#
# **body Style**: The body style of the car, such as "Sedan," "SUV," etc
#
# **Phone**: The phone number of the customer who purchased the car
#
# **Dealer_Region**: The geographical region of the car dealer, such as "North," "South," etc.

# %% [markdown]
# # **Questions:**
# Q1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Prompt for file upload
from google.colab import files
uploaded = files.upload()

# Get the file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
df = pd.read_csv(file_name)
print("Dataset loaded successfully!")

# Validate column names
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if needed
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Handle missing values
df = df.dropna(subset=["Price"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Group by dealer and calculate the average sellin g price
avg_price_per_dealer = df.groupby("Dealer_Name")["Price"].mean()

# Sort for better visualization
avg_price_per_dealer_sorted = avg_price_per_dealer.sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
avg_price_per_dealer_sorted.plot(kind="bar", color="skyblue")
plt.xlabel("Dealer Name")
plt.ylabel("Average Selling Price ($)")
plt.title("Average Selling Price of Cars Per Dealer")
plt.xticks(rotation=45)
plt.show()
plt.savefig("plot.png", dpi=300)  # Saves in high quality

# %% [markdown]
# Q2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset (ensure correct file path)
try:
    df = pd.read_csv("Car_Sale.csv")
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please check the file path and ensure the dataset is available.")
    exit()

# Check dataset columns to avoid errors
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if needed
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Handle missing values
df = df.dropna(subset=["Price"])

# Convert 'Price' to numeric for analysis
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Calculate standard deviation of prices for each car brand
price_variation = df.groupby("Company")["Price"].std()

# Find the brand with the highest price variation
highest_variation_brand = price_variation.idxmax()
highest_variation_value = price_variation.max()

print(f"The car brand with the highest price variation is {highest_variation_brand} with a standard deviation of {highest_variation_value:.2f}.")

# Sort price variations for visualization
price_variation_sorted = price_variation.sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 6))
price_variation_sorted.plot(kind="bar", color="skyblue")
plt.xlabel("Car Brand (Company)")
plt.ylabel("Price Variation (Standard Deviation)")
plt.title("Price Variation Across Car Brands")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q3. What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset in Colab manually before running this code
from google.colab import files
uploaded = files.upload()

# Get correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display available columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Transmission'
df = df.dropna(subset=["Price", "Transmission"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Calculate Interquartile Range (IQR) for each Transmission Type
iqr_values = df.groupby("Transmission")["Price"].quantile([0.25, 0.75]).unstack()
iqr_values["IQR"] = iqr_values[0.75] - iqr_values[0.25]

print("\nInterquartile Ranges (IQR) for each transmission type:")
print(iqr_values)

# Create a box plot to visualize price distribution by transmission type
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["Transmission"], y=df["Price"], palette="coolwarm")
plt.xlabel("Transmission Type")
plt.ylabel("Car Price ($)")
plt.title("Distribution of Car Prices by Transmission Type")
plt.show()

# %% [markdown]
# Q4. What is the distribution of car prices across different regions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Dealer_Region'
df = df.dropna(subset=["Price", "Dealer_Region"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Calculate price distribution across regions
price_distribution = df.groupby("Dealer_Region")["Price"].describe()

print("\nPrice Distribution Across Regions:")
print(price_distribution)

# Create a box plot to visualize price distribution by region
plt.figure(figsize=(12, 6))
sns.boxplot(x=df["Dealer_Region"], y=df["Price"], palette="coolwarm")
plt.xlabel("Dealer Region")
plt.ylabel("Car Price ($)")
plt.title("Distribution of Car Prices Across Different Regions")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q5. What is the distribution of cars based on body styles?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Validate dataset columns
print("Available columns:", df.columns)

# Rename 'Body Style' column for consistency
df.rename(columns={"Body Style": "Body_Style"}, inplace=True)

# Drop missing values in 'Body_Style'
df = df.dropna(subset=["Body_Style"])

# Count occurrences of each body style
body_style_counts = df["Body_Style"].value_counts()

print("\nDistribution of Cars Based on Body Styles:")
print(body_style_counts)

# Create a bar chart for visualization
plt.figure(figsize=(12, 6))
sns.barplot(x=body_style_counts.index, y=body_style_counts.values, palette="coolwarm")
plt.xlabel("Body Style")
plt.ylabel("Number of Cars")
plt.title("Distribution of Cars Based on Body Styles")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q6. How does the average selling price of cars vary by customer gender and annual income?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price', 'Gender', and 'Annual Income'
df = df.dropna(subset=["Price", "Gender", "Annual Income"])

# Convert 'Price' and 'Annual Income' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Annual Income"] = pd.to_numeric(df["Annual Income"], errors="coerce")
df = df.dropna(subset=["Price", "Annual Income"])

# Calculate average selling price by gender
avg_price_by_gender = df.groupby("Gender")["Price"].mean()

print("\nAverage Selling Price by Gender:")
print(avg_price_by_gender)

# Group by income range (binning)
df["Income_Group"] = pd.cut(df["Annual Income"], bins=[0, 50000, 100000, 200000, 500000, 1000000],
                            labels=["Low", "Lower-Mid", "Mid", "Upper-Mid", "High"])

avg_price_by_income = df.groupby("Income_Group")["Price"].mean()

print("\nAverage Selling Price by Income Group:")
print(avg_price_by_income)

# Visualizing the trends
plt.figure(figsize=(12, 6))

# Bar plot for gender-based price variation
plt.subplot(1, 2, 1)
sns.barplot(x=avg_price_by_gender.index, y=avg_price_by_gender.values, palette="coolwarm")
plt.xlabel("Gender")
plt.ylabel("Average Selling Price ($)")
plt.title("Average Selling Price by Gender")

# Bar plot for income-based price variation
plt.subplot(1, 2, 2)
sns.barplot(x=avg_price_by_income.index, y=avg_price_by_income.values, palette="coolwarm")
plt.xlabel("Income Group")
plt.ylabel("Average Selling Price ($)")
plt.title("Average Selling Price by Income Group")

plt.tight_layout()
plt.show()

# %% [markdown]
# Q7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Dealer_Region'
df = df.dropna(subset=["Price", "Dealer_Region"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Calculate price distribution across regions
price_distribution = df.groupby("Dealer_Region")["Price"].describe()

print("\nPrice Distribution Across Regions:")
print(price_distribution)

# Count occurrences of cars sold per region
cars_sold_by_region = df["Dealer_Region"].value_counts()

print("\nNumber of Cars Sold by Region:")
print(cars_sold_by_region)

# Visualizing the trends
plt.figure(figsize=(12, 6))

# Box plot for price distribution by region
plt.subplot(1, 2, 1)
sns.boxplot(x=df["Dealer_Region"], y=df["Price"], palette="coolwarm")
plt.xlabel("Dealer Region")
plt.ylabel("Car Price ($)")
plt.title("Distribution of Car Prices Across Different Regions")
plt.xticks(rotation=45)

# Bar plot for number of cars sold per region
plt.subplot(1, 2, 2)
sns.barplot(x=cars_sold_by_region.index, y=cars_sold_by_region.values, palette="coolwarm")
plt.xlabel("Dealer Region")
plt.ylabel("Number of Cars Sold")
plt.title("Number of Cars Sold by Region")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Q8. How does the average car price differ between cars with different engine sizes?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Engine'
df = df.dropna(subset=["Price", "Engine"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Calculate average selling price by engine size
avg_price_by_engine = df.groupby("Engine")["Price"].mean()

print("\nAverage Car Price by Engine Size:")
print(avg_price_by_engine)

# Create a bar plot to visualize price trends by engine size
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_price_by_engine.index, y=avg_price_by_engine.values, palette="coolwarm")
plt.xlabel("Engine Size")
plt.ylabel("Average Car Price ($)")
plt.title("Average Car Price by Engine Size")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q9. How do car prices vary based on the customer’s annual income bracket?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Annual Income'
df = df.dropna(subset=["Price", "Annual Income"])

# Convert 'Price' and 'Annual Income' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Annual Income"] = pd.to_numeric(df["Annual Income"], errors="coerce")
df = df.dropna(subset=["Price", "Annual Income"])

# Define income brackets
df["Income_Group"] = pd.cut(df["Annual Income"], bins=[0, 50000, 100000, 200000, 500000, 1000000],
                            labels=["Low", "Lower-Mid", "Mid", "Upper-Mid", "High"])

# Calculate average car price per income group
avg_price_by_income = df.groupby("Income_Group")["Price"].mean()

print("\nAverage Car Price by Income Bracket:")
print(avg_price_by_income)

# Create a bar plot to visualize price trends by income bracket
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_price_by_income.index, y=avg_price_by_income.values, palette="coolwarm")
plt.xlabel("Income Bracket")
plt.ylabel("Average Car Price ($)")
plt.title("Average Car Price by Customer's Annual Income Bracket")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Model'
df = df.dropna(subset=["Price", "Model"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Count the number of cars sold per model
top_models = df["Model"].value_counts().head(5)

print("\nTop 5 Car Models with Highest Number of Sales:")
print(top_models)

# Filter dataset for top 5 models
df_top_models = df[df["Model"].isin(top_models.index)]

# Create a box plot to visualize price distribution of top 5 models
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_top_models["Model"], y=df_top_models["Price"], palette="coolwarm")
plt.xlabel("Car Model")
plt.ylabel("Selling Price ($)")
plt.title("Price Distribution of Top 5 Best-Selling Car Models")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price', 'Engine', and 'Color'
df = df.dropna(subset=["Price", "Engine", "Color"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Group by engine size and color, then calculate average price
avg_price_by_engine_color = df.groupby(["Engine", "Color"])["Price"].mean().unstack()

print("\nAverage Car Price by Engine Size and Color:")
print(avg_price_by_engine_color)

# Calculate average price for each color
avg_price_by_color = df.groupby("Color")["Price"].mean().sort_values(ascending=False)

print("\nColors with the Highest Average Price:")
print(avg_price_by_color.head(5))

# Visualizing the trends
plt.figure(figsize=(12, 6))

# Heatmap for price variation by engine size and color
sns.heatmap(avg_price_by_engine_color, cmap="coolwarm", annot=True, fmt=".0f")
plt.xlabel("Car Color")
plt.ylabel("Engine Size")
plt.title("Car Price Variation by Engine Size and Color")
plt.xticks(rotation=45)
plt.show()

# Bar plot for highest-priced colors
plt.figure(figsize=(10, 5))
sns.barplot(x=avg_price_by_color.index, y=avg_price_by_color.values, palette="coolwarm")
plt.xlabel("Car Color")
plt.ylabel("Average Price ($)")
plt.title("Top 5 Colors with the Highest Car Prices")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q12. Is there any seasonal trend in car sales based on the date of sale?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Date'
df = df.dropna(subset=["Price", "Date"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Convert 'Date' to datetime format
df["Date"] = pd.to_datetime(df["Date"])

# Extract month and year from the date
df["Month"] = df["Date"].dt.month
df["Year"] = df["Date"].dt.year

# Calculate total sales per month
monthly_sales = df.groupby("Month")["Price"].count()

print("\nTotal Car Sales by Month:")
print(monthly_sales)

# Calculate average price per month to check seasonal trends
avg_price_by_month = df.groupby("Month")["Price"].mean()

print("\nAverage Car Price by Month:")
print(avg_price_by_month)

# Visualizing seasonal trends
plt.figure(figsize=(12, 6))

# Line plot for total sales by month
plt.subplot(1, 2, 1)
sns.lineplot(x=monthly_sales.index, y=monthly_sales.values, marker="o", color="blue")
plt.xlabel("Month")
plt.ylabel("Number of Cars Sold")
plt.title("Seasonal Trend in Car Sales")
plt.xticks(range(1, 13), ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                           "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

# Line plot for average price per month
plt.subplot(1, 2, 2)
sns.lineplot(x=avg_price_by_month.index, y=avg_price_by_month.values, marker="o", color="red")
plt.xlabel("Month")
plt.ylabel("Average Car Price ($)")
plt.title("Average Car Price by Month")
plt.xticks(range(1, 13), ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                           "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

plt.tight_layout()
plt.show()

# %% [markdown]
# Q13. How does the car price distribution change when considering different combinations of body style and transmission type?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price' and 'Date'
df = df.dropna(subset=["Price", "Date"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Convert 'Date' to datetime format
df["Date"] = pd.to_datetime(df["Date"])

# Extract month and year from the date
df["Month"] = df["Date"].dt.month
df["Year"] = df["Date"].dt.year

# Calculate total sales per month
monthly_sales = df.groupby("Month")["Price"].count()

print("\nTotal Car Sales by Month:")
print(monthly_sales)

# Calculate average price per month to check seasonal trends
avg_price_by_month = df.groupby("Month")["Price"].mean()

print("\nAverage Car Price by Month:")
print(avg_price_by_month)

# Visualizing seasonal trends
plt.figure(figsize=(12, 6))

# Line plot for total sales by month
plt.subplot(1, 2, 1)
sns.lineplot(x=monthly_sales.index, y=monthly_sales.values, marker="o", color="blue")
plt.xlabel("Month")
plt.ylabel("Number of Cars Sold")
plt.title("Seasonal Trend in Car Sales")
plt.xticks(range(1, 13), ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                           "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

# Line plot for average price per month
plt.subplot(1, 2, 2)
sns.lineplot(x=avg_price_by_month.index, y=avg_price_by_month.values, marker="o", color="red")
plt.xlabel("Month")
plt.ylabel("Average Car Price ($)")
plt.title("Average Car Price by Month")
plt.xticks(range(1, 13), ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                           "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

plt.tight_layout()
plt.show()

# %% [markdown]
# Q14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset in Google Colab
from google.colab import files
uploaded = files.upload()

# Get correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Clean and convert columns to numeric
df["Price"] = df["Price"].astype(str).str.replace(",", "").str.replace("$", "").astype(float)
df["Engine"] = df["Engine"].astype(str).str.extract(r'(\d+)').astype(float)
df["Annual Income"] = df["Annual Income"].astype(str).str.replace(",", "").astype(float)

# Fill missing values before dropping all NaNs
df["Price"].fillna(df["Price"].median(), inplace=True)
df["Engine"].fillna(df["Engine"].median(), inplace=True)
df["Annual Income"].fillna(df["Annual Income"].median(), inplace=True)

# Check final numeric data
print("\nNumeric Data Preview:")
print(df[["Price", "Engine", "Annual Income"]].describe())

# Compute correlation matrix
numeric_df = df[["Price", "Engine", "Annual Income"]]

if not numeric_df.empty:
    correlation_matrix = numeric_df.corr()
    print("\nCorrelation Matrix:")
    print(correlation_matrix)

    # Visualizing correlation
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
    plt.title("Correlation Between Car Price, Engine Size, and Annual Income")
    plt.show()

    # Pairplot to analyze feature interaction
    sns.pairplot(df, vars=["Price", "Engine", "Annual Income"], diag_kind="kde")
    plt.suptitle("Pairwise Relationship Between Car Price, Engine Size, and Annual Income", y=1.02)
    plt.show()
else:
    print("Error: No numeric columns found in the dataset.")

# %% [markdown]
# Q15. How does the average car price vary across different car models and engine types?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price', 'Model', and 'Engine'
df = df.dropna(subset=["Price", "Model", "Engine"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Group by model and engine type, then calculate average price
avg_price_by_model_engine = df.groupby(["Model", "Engine"])["Price"].mean().unstack()

print("\nAverage Car Price by Model and Engine Type:")
print(avg_price_by_model_engine)

# Visualizing the trends
plt.figure(figsize=(12, 6))

# Heatmap for price variation by model and engine type
sns.heatmap(avg_price_by_model_engine, cmap="coolwarm", annot=True, fmt=".0f")
plt.xlabel("Engine Type")
plt.ylabel("Car Model")
plt.title("Car Price Variation by Model and Engine Type")
plt.xticks(rotation=45)
plt.show()
plt.savefig("plot.png", dpi=300)  # Saves in high quality
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price', 'Model', and 'Engine'
df = df.dropna(subset=["Price", "Model", "Engine"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Group by model and engine type, then calculate average price
avg_price_by_model_engine = df.groupby(["Model", "Engine"])["Price"].mean().unstack()

print("\nAverage Car Price by Model and Engine Type:")
print(avg_price_by_model_engine)

# Visualizing the trends
plt.figure(figsize=(12, 6))

# Heatmap for price variation by model and engine type
sns.heatmap(avg_price_by_model_engine, cmap="coolwarm", annot=True, fmt=".0f")
plt.xlabel("Engine Type")
plt.ylabel("Car Model")
plt.title("Car Price Variation by Model and Engine Type")
plt.xticks(rotation=45)
plt.show()
plt.savefig("plot.png", dpi=300)  # Saves in high quality
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload dataset manually in Google Colab before running this code
from google.colab import files
uploaded = files.upload()

# Get the correct file name dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
try:
    df = pd.read_csv(file_name)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please upload the dataset and try again.")
    exit()

# Display dataset columns
print("Dataset columns:", df.columns)

# Rename 'Price ($)' to 'Price' if necessary
df.rename(columns={"Price ($)": "Price"}, inplace=True)

# Drop missing values in 'Price', 'Model', and 'Engine'
df = df.dropna(subset=["Price", "Model", "Engine"])

# Convert 'Price' to numeric
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"])

# Group by model and engine type, then calculate average price
avg_price_by_model_engine = df.groupby(["Model", "Engine"])["Price"].mean().unstack()

print("\nAverage Car Price by Model and Engine Type:")
print(avg_price_by_model_engine)

# Visualizing the trends
plt.figure(figsize=(12, 6))

# Heatmap for price variation by model and engine type
sns.heatmap(avg_price_by_model_engine, cmap="coolwarm", annot=True, fmt=".0f")
plt.xlabel("Engine Type")
plt.ylabel("Car Model")
plt.title("Car Price Variation by Model and Engine Type")
plt.xticks(rotation=45)
plt.show()
plt.savefig("plot.png", dpi=300)  # Saves in high quality

# %% [markdown]
# # **EDA 3**
# # Amazon Sales Data
#
# **Description:**
#
# This dataset contains information on 1K+ Amazon products, including their ratings, reviews, and other details.
#
# # Features:
# product_id: Unique identifier for each product
#
# product_name: Name of the product
#
# category: Category of the product
#
# discounted_price: Discounted price of the product
#
# actual_price: Actual price of the product
#
# discount_percentage: Percentage of discount for the product
#
# rating: Rating of the product (1-5)
#
# rating_count: Number of people who voted for the Amazon rating
#
# about_product: Description about the product
#
# user_id: ID of the user who wrote the review
#
# user_name: Name of the user who wrote the review
#
# review_id: ID of the user review
#
# review_title: Short review
#
# review_content: Long review
#
# img_link: Image link of the product
#
# product_link: Official website link of the product
#
# # Questions:
# Q1. What is the average rating for each product category?

# %%
import pandas as pd
import os

# 🔹 Step 1: Upload File in Google Colab (if needed)
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
try:
    df = pd.read_csv(file_name)
    print("\n✅ Dataset loaded successfully!")
except FileNotFoundError:
    print(f"❌ Error: The file '{file_name}' was not found. Please upload the correct file.")

# 🔹 Step 4: Check available columns
print("\nAvailable Columns:", df.columns)

# 🔹 Step 5: Ensure necessary columns exist
if "category" in df.columns and "rating" in df.columns:
    # Convert 'rating' to numeric values, handling missing values
    df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

    # Drop rows with NaN values in 'rating'
    df.dropna(subset=["rating"], inplace=True)

    # Compute average rating for each category
    avg_rating = df.groupby("category")["rating"].mean().reset_index()

    # Display results
    print("\n📊 Average Rating Per Category:")
    print(avg_rating)

else:
    print("❌ Error: Columns 'category' or 'rating' not found in the dataset.")

# %% [markdown]
# Q2. What are the top rating_count products by category?

# %%
import pandas as pd
import os

# 🔹 Step 1: Upload File in Google Colab (if needed)
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
try:
    df = pd.read_csv(file_name)
    print("\n✅ Dataset loaded successfully!")
except FileNotFoundError:
    print(f"❌ Error: The file '{file_name}' was not found. Please upload the correct file.")

# 🔹 Step 4: Check available columns
print("\nAvailable Columns:", df.columns)

# 🔹 Step 5: Ensure necessary columns exist
if "category" in df.columns and "rating_count" in df.columns and "product_name" in df.columns:
    # Convert 'rating_count' to numeric values, handling missing values
    df["rating_count"] = pd.to_numeric(df["rating_count"], errors="coerce")

    # Drop rows with missing values in 'rating_count'
    df.dropna(subset=["rating_count"], inplace=True)

    # 🔹 Step 6: Get the top-rated products for each category
    top_products = df.loc[df.groupby("category")["rating_count"].idxmax(), ["category", "product_name", "rating_count"]]

    # Display results
    print("\n📊 Top Rating Count Products by Category:")
    print(top_products)

else:
    print("❌ Error: Columns 'category' or 'rating_count' not found in the dataset.")

# %% [markdown]
# Q3. What is the distribution of discounted prices vs. actual prices?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 🔹 Step 1: Upload file in Google Colab
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 4: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 5: Ensure necessary columns exist
if "discounted_price" in df.columns and "actual_price" in df.columns:
    # Convert prices to numeric values (handling missing data)
    df["discounted_price"] = pd.to_numeric(df["discounted_price"], errors="coerce")
    df["actual_price"] = pd.to_numeric(df["actual_price"], errors="coerce")

    # Drop rows with NaN values in price columns
    df.dropna(subset=["discounted_price", "actual_price"], inplace=True)

    # 🔹 Step 6: Plot histograms to compare price distributions
    plt.figure(figsize=(12,6))
    sns.histplot(df["actual_price"], bins=50, color="red", label="Actual Price", alpha=0.6)
    sns.histplot(df["discounted_price"], bins=50, color="green", label="Discounted Price", alpha=0.6)
    plt.xlabel("Price")
    plt.ylabel("Frequency")
    plt.title("Distribution of Actual vs. Discounted Prices")
    plt.legend()
    plt.show()

    # 🔹 Step 7: Box Plot to visualize spread
    plt.figure(figsize=(10,5))
    sns.boxplot(data=df[["actual_price", "discounted_price"]])
    plt.ylabel("Price")
    plt.title("Boxplot of Actual vs. Discounted Prices")
    plt.xticks(ticks=[0, 1], labels=["Actual Price", "Discounted Price"])
    plt.show()

    # 🔹 Step 8: Scatter Plot to visualize price relationship
    plt.figure(figsize=(10,6))
    sns.scatterplot(x=df["actual_price"], y=df["discounted_price"], alpha=0.6)
    plt.xlabel("Actual Price")
    plt.ylabel("Discounted Price")
    plt.title("Actual Price vs. Discounted Price")
    plt.show()

else:
    print("❌ Error: Columns 'discounted_price' or 'actual_price' not found in the dataset.")

# %% [markdown]
# Q4. How does the average discount percentage vary across categories?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 🔹 Step 1: Upload File in Google Colab
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 4: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 5: Ensure necessary columns exist
if "category" in df.columns and "discount_percentage" in df.columns:
    # Convert discount percentage to numeric values
    df["discount_percentage"] = pd.to_numeric(df["discount_percentage"], errors="coerce")

    # Drop rows with missing values
    df.dropna(subset=["discount_percentage"], inplace=True)

    # 🔹 Step 6: Compute average discount percentage per category
    avg_discount = df.groupby("category")["discount_percentage"].mean().reset_index()

    # Display results
    print("\n📊 Average Discount Percentage by Category:")
    print(avg_discount)

    # 🔹 Step 7: Visualization
    plt.figure(figsize=(12,6))
    sns.barplot(x="category", y="discount_percentage", data=avg_discount, palette="coolwarm")
    plt.xticks(rotation=45)
    plt.xlabel("Category")
    plt.ylabel("Average Discount Percentage")
    plt.title("Average Discount Percentage Across Categories")
    plt.show()

else:
    print("❌ Error: Columns 'category' or 'discount_percentage' not found in the dataset.")

# %% [markdown]
# Q5. What are the most popular product names?

# %%
import pandas as pd
import os

# 🔹 Step 1: Upload File in Google Colab (if needed)
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
try:
    df = pd.read_csv(file_name)
    print("\n✅ Dataset loaded successfully!")
except FileNotFoundError:
    print(f"❌ Error: The file '{file_name}' was not found. Please upload the correct file.")

# 🔹 Step 4: Check available columns
print("\nAvailable Columns:", df.columns)

# 🔹 Step 5: Ensure necessary column exists
if "product_name" in df.columns:
    # 🔹 Step 6: Count occurrences of product names
    top_products = df["product_name"].value_counts().head(10)

    # Display results
    print("\n📊 Most Popular Product Names:")
    print(top_products)

else:
    print("❌ Error: Column 'product_name' not found in the dataset.")

# %% [markdown]
# Q6. What are the most popular product keywords?

# %%
import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# 🔹 Step 1: Upload File in Google Colab
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 4: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 5: Ensure 'product_name' or 'about_product' column exists
if "product_name" in df.columns:
    text_column = "product_name"
elif "about_product" in df.columns:
    text_column = "about_product"
else:
    print("❌ Error: No suitable column found for keyword extraction.")
    exit()

# 🔹 Step 6: Process text data to extract keywords
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)  # Remove special characters
    return text

df[text_column] = df[text_column].apply(clean_text)

# 🔹 Step 7: Count keyword frequencies
all_words = " ".join(df[text_column]).split()
word_freq = Counter(all_words)

# 🔹 Step 8: Display top keywords
top_keywords = word_freq.most_common(10)
print("\n📊 Most Popular Product Keywords:")
print(pd.DataFrame(top_keywords, columns=["Keyword", "Frequency"]))

# 🔹 Step 9: Visualization - Word Cloud
plt.figure(figsize=(12,6))
wordcloud = WordCloud(width=1000, height=500, background_color="white").generate(" ".join(all_words))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Most Common Product Keywords")
plt.show()

# 🔹 Step 10: Visualization - Bar Chart
plt.figure(figsize=(12,6))
sns.barplot(x=[k[0] for k in top_keywords], y=[k[1] for k in top_keywords], palette="coolwarm")
plt.xlabel("Keyword")
plt.ylabel("Frequency")
plt.title("Top 10 Most Popular Product Keywords")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q7. What are the most popular product reviews?

# %%
import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# 🔹 Step 1: Upload File in Google Colab
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 4: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 5: Ensure necessary columns exist
if "product_name" in df.columns and "review_content" in df.columns and "rating_count" in df.columns:
    # Convert 'rating_count' to numeric values
    df["rating_count"] = pd.to_numeric(df["rating_count"], errors="coerce")

    # Drop rows with missing values
    df.dropna(subset=["rating_count", "review_content"], inplace=True)

    # 🔹 Step 6: Get the most-reviewed products
    top_reviewed_products = df.nlargest(10, "rating_count")[["product_name", "rating_count", "review_content"]]
    print("\n📊 Top 10 Most Reviewed Products:")
    print(top_reviewed_products[["product_name", "rating_count"]])

    # 🔹 Step 7: Process review text for keyword extraction
    def clean_text(text):
        text = str(text).lower()
        text = re.sub(r"[^a-z\s]", "", text)  # Remove special characters
        return text

    df["review_content"] = df["review_content"].apply(clean_text)

    # 🔹 Step 8: Count keyword frequencies in reviews
    all_words = " ".join(df["review_content"]).split()
    word_freq = Counter(all_words)

    # 🔹 Step 9: Display top keywords from reviews
    top_keywords = word_freq.most_common(10)
    print("\n📊 Most Common Words in Reviews:")
    print(pd.DataFrame(top_keywords, columns=["Keyword", "Frequency"]))

    # 🔹 Step 10: Visualization - Word Cloud
    plt.figure(figsize=(12,6))
    wordcloud = WordCloud(width=1000, height=500, background_color="white").generate(" ".join(all_words))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.title("Word Cloud of Most Common Product Review Keywords")
    plt.show()

else:
    print("❌ Error: Required columns ('product_name', 'review_content', 'rating_count') not found in the dataset.")

# %% [markdown]
# Q8. What is the correlation between discounted_price and rating?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 🔹 Step 1: Upload File in Google Colab
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 4: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 5: Ensure necessary columns exist
if "discounted_price" in df.columns and "rating" in df.columns:
    # Convert columns to numeric values
    df["discounted_price"] = pd.to_numeric(df["discounted_price"], errors="coerce")
    df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

    # Drop rows with missing values
    df.dropna(subset=["discounted_price", "rating"], inplace=True)

    # 🔹 Step 6: Compute correlation coefficient
    correlation = df["discounted_price"].corr(df["rating"])
    print(f"\n📊 Correlation between Discounted Price and Rating: {correlation:.2f}")

    # 🔹 Step 7: Visualization - Scatter Plot
    plt.figure(figsize=(10,6))
    sns.scatterplot(x=df["discounted_price"], y=df["rating"], alpha=0.6)
    plt.xlabel("Discounted Price")
    plt.ylabel("Rating")
    plt.title("Correlation Between Discounted Price and Rating")
    plt.show()

else:
    print("❌ Error: Columns 'discounted_price' or 'rating' not found in the dataset.")

# %% [markdown]
# Q9. What are the Top 5 categories based on the highest ratings?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 🔹 Step 1: Upload File in Google Colab
from google.colab import files
uploaded = files.upload()

# 🔹 Step 2: Get the correct filename dynamically
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 3: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 4: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 5: Ensure necessary columns exist
if "category" in df.columns and "rating" in df.columns:
    # Convert 'rating' to numeric values
    df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

    # Drop rows with missing values
    df.dropna(subset=["rating"], inplace=True)

    # 🔹 Step 6: Compute average rating per category
    avg_rating = df.groupby("category")["rating"].mean().reset_index()

    # 🔹 Step 7: Get the Top 5 categories
    top_categories = avg_rating.nlargest(5, "rating")

    # Display results
    print("\n📊 Top 5 Categories Based on Highest Ratings:")
    print(top_categories)

    # 🔹 Step 8: Visualization
    plt.figure(figsize=(12,6))
    sns.barplot(x="category", y="rating", data=top_categories, palette="coolwarm")
    plt.xticks(rotation=45)
    plt.xlabel("Category")
    plt.ylabel("Average Rating")
    plt.title("Top 5 Categories Based on Highest Ratings")
    plt.show()

else:
    print("❌ Error: Columns 'category' or 'rating' not found in the dataset.")

# %% [markdown]
# Q10. Identify any potential areas for improvement or optimization based on the data analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 3: Check for missing values
missing_values = df.isnull().sum()
print("\n📊 Missing Values Summary:")
print(missing_values[missing_values > 0])

# 🔹 Step 4: Drop rows with missing critical values (rating, discounted_price, actual_price)
df.dropna(subset=["rating", "discounted_price", "actual_price"], inplace=True)

# 🔹 Step 5: Convert columns to numeric for analysis
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")
df["discounted_price"] = pd.to_numeric(df["discounted_price"], errors="coerce")
df["actual_price"] = pd.to_numeric(df["actual_price"], errors="coerce")
df["discount_percentage"] = pd.to_numeric(df["discount_percentage"], errors="coerce")

# 🔹 Step 6: Identify outliers in discount percentage using IQR method
Q1 = df["discount_percentage"].quantile(0.25)
Q3 = df["discount_percentage"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_filtered = df[(df["discount_percentage"] >= lower_bound) & (df["discount_percentage"] <= upper_bound)]
print(f"\n🚀 Removed outliers - Original size: {len(df)}, Cleaned size: {len(df_filtered)}")

# 🔹 Step 7: Correlation Matrix to identify optimization insights
corr_matrix = df_filtered[["discounted_price", "actual_price", "discount_percentage", "rating"]].corr()
print("\n📊 Correlation Matrix:")
print(corr_matrix)

# 🔹 Step 8: Heatmap for Correlation Analysis
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Key Features")
plt.show()

# 🔹 Step 9: Word Cloud for most frequently reviewed keywords
plt.figure(figsize=(12,6))
wordcloud = WordCloud(width=1000, height=500, background_color="white").generate(" ".join(df_filtered["review_content"].dropna()))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Most Common Product Review Keywords")
plt.show()

# %% [markdown]
# # **EDA 4**
# **Dataset:**
#
# The dataset titled "Spotify Data: Popular Hip-hop Artists and Tracks" provides a curated collection of approximately 500 entries showcasing the vibrant realm of hip-hop music. These entries meticulously compile the most celebrated hip-hop tracks and artists, reflecting their significant influence on the genre's landscape. Each entry not only highlights the popularity and musical composition of the tracks but also underscores the creative prowess of the artists and their profound impact on global listeners.
#
# **Application in Data Science:**
#
# This dataset serves as a valuable resource for various data science explorations. Analysts can delve into trend analysis to discern the popularity dynamics of hit hip-hop tracks over recent years. Additionally, the dataset enables network analysis to uncover collaborative patterns among top artists, shedding light on the genre's evolving collaborative landscape. Furthermore, it facilitates the development of predictive models aimed at forecasting track popularity based on diverse features, offering insights for artists, producers, and marketers.
#
# **Column Descriptors:**
#
# Artist: The name of the artist, providing direct attribution to the creative mind behind the track. Track Name: The title of the track, encapsulating its identity and essence. Popularity: A numeric score reflecting the track's reception and appeal among Spotify listeners. Duration (ms): The track's length in milliseconds, detailing the temporal extent of the musical experience. Track ID: A unique identifier within Spotify's ecosystem enabling direct access to the track for further
#
# # **Questions:**
# Q1. Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful.

# %%
import pandas as pd
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
try:
    df = pd.read_csv(file_name)
    print("\n✅ Dataset loaded successfully!")
except FileNotFoundError:
    print(f"❌ Error: The file '{file_name}' was not found. Please upload the correct file.")

# 🔹 Step 3: Check for Missing Values
missing_values = df.isnull().sum()
print("\n📊 Missing Values Summary:")
print(missing_values[missing_values > 0])

# 🔹 Step 4: Handle Missing Values
df.fillna(df.mean(numeric_only=True), inplace=True)  # Fills missing numeric values with column mean
df.dropna(inplace=True)  # Drops remaining rows with missing values
print("\n✅ Missing values handled successfully!")

# 🔹 Step 5: Check for Duplicate Rows
duplicate_rows = df.duplicated().sum()
print(f"\n📊 Duplicate Rows Found: {duplicate_rows}")

# 🔹 Step 6: Remove Duplicate Rows
df.drop_duplicates(inplace=True)
print("\n✅ Duplicate rows removed successfully!")

# 🔹 Step 7: Summary of Cleaned Data
print("\n📊 DataFrame Summary After Cleaning:")
print(df.info())

# 🔹 Step 8: Save Cleaned Data (Optional)
df.to_csv("cleaned_data.csv", index=False)
print("\n✅ Cleaned dataset saved as 'cleaned_data.csv'")

# %% [markdown]
# Q2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 3: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 4: Ensure necessary column exists
if "Popularity" in df.columns:
    # Convert popularity values to numeric (handling errors)
    df["Popularity"] = pd.to_numeric(df["Popularity"], errors="coerce")

    # Drop rows with missing popularity values
    df.dropna(subset=["Popularity"], inplace=True)

    # 🔹 Step 5: Visualize Popularity Distribution
    plt.figure(figsize=(12,6))
    sns.histplot(df["Popularity"], bins=30, kde=True, color="blue")
    plt.xlabel("Popularity Score")
    plt.ylabel("Frequency")
    plt.title("Distribution of Popularity Among Tracks")
    plt.show()

else:
    print("❌ Error: Column 'Popularity' not found in the dataset.")

# %% [markdown]
# Q3. Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 3: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 4: Ensure necessary columns exist
if "Popularity" in df.columns and "Duration (ms)" in df.columns:
    # Convert duration from milliseconds to minutes
    df["Duration (min)"] = df["Duration (ms)"] / 60000

    # Drop rows with missing values
    df.dropna(subset=["Popularity", "Duration (min)"], inplace=True)

    # 🔹 Step 5: Scatter Plot to visualize correlation
    plt.figure(figsize=(10,6))
    sns.scatterplot(x=df["Duration (min)"], y=df["Popularity"], alpha=0.6)
    plt.xlabel("Track Duration (minutes)")
    plt.ylabel("Popularity Score")
    plt.title("Track Popularity vs. Duration")
    plt.show()

else:
    print("❌ Error: Columns 'Popularity' or 'Duration (ms)' not found in the dataset.")

# %% [markdown]
# Q4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 3: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 4: Ensure necessary column exists
if "Artist" in df.columns:
    # 🔹 Step 5: Count the number of tracks per artist
    artist_counts = df["Artist"].value_counts().head(10)  # Display top 10 artists

    # Display results
    print("\n📊 Top 10 Artists with Highest Number of Tracks:")
    print(artist_counts)

    # 🔹 Step 6: Visualization - Count Plot
    plt.figure(figsize=(12,6))
    sns.barplot(x=artist_counts.index, y=artist_counts.values, palette="coolwarm")
    plt.xticks(rotation=45)
    plt.xlabel("Artist")
    plt.ylabel("Number of Tracks")
    plt.title("Top 10 Artists with Most Tracks in Dataset")
    plt.show()

else:
    print("❌ Error: Column 'Artist' not found in the dataset.")

# %% [markdown]
# Q5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.

# %%
import pandas as pd
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 3: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 4: Ensure necessary columns exist
if "Popularity" in df.columns and "Artist" in df.columns and "Track Name" in df.columns:
    # Convert popularity values to numeric (handling errors)
    df["Popularity"] = pd.to_numeric(df["Popularity"], errors="coerce")

    # Drop rows with missing popularity values
    df.dropna(subset=["Popularity"], inplace=True)

    # 🔹 Step 5: Get the top 5 least popular tracks
    least_popular_tracks = df.nsmallest(5, "Popularity")[["Artist", "Track Name", "Popularity"]]

    # Display results
    print("\n📊 Top 5 Least Popular Tracks:")
    print(least_popular_tracks)

else:
    print("❌ Error: Required columns ('Popularity', 'Artist', 'Track Name') not found in the dataset.")

# %% [markdown]
# Q6. Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist.

# %%
import pandas as pd
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 3: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 4: Ensure necessary columns exist
if "Artist" in df.columns and "Popularity" in df.columns:
    # Convert popularity values to numeric (handling errors)
    df["Popularity"] = pd.to_numeric(df["Popularity"], errors="coerce")

    # Drop rows with missing popularity values
    df.dropna(subset=["Popularity"], inplace=True)

    # 🔹 Step 5: Calculate average popularity per artist
    avg_popularity = df.groupby("Artist")["Popularity"].mean().reset_index()

    # 🔹 Step 6: Get the top 5 most popular artists
    top_artists = avg_popularity.nlargest(5, "Popularity")

    # Display results
    print("\n📊 Top 5 Most Popular Artists Based on Average Popularity:")
    print(top_artists)

else:
    print("❌ Error: Required columns ('Artist', 'Popularity') not found in the dataset.")

# %% [markdown]
# Q7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.

# %%
import pandas as pd
from google.colab import files

# 🔹 Step 1: Upload File in Google Colab
uploaded = files.upload()
file_name = list(uploaded.keys())[0]  # Extract uploaded filename
print(f"Using file: {file_name}")

# 🔹 Step 2: Load the dataset
df = pd.read_csv(file_name)
print("\n✅ Dataset loaded successfully!")

# 🔹 Step 3: Check available columns
print("Available Columns:", df.columns)

# 🔹 Step 4: Ensure necessary columns exist
if "Artist" in df.columns and "Track Name" in df.columns and "Popularity" in df.columns:
    # Convert popularity values to numeric
    df["Popularity"] = pd.to_numeric(df["Popularity"], errors="coerce")

    # Drop rows with missing popularity values
    df.dropna(subset=["Popularity"], inplace=True)

    # 🔹 Step 5: Identify top 5 most popular artists based on average popularity
    avg_popularity = df.groupby("Artist")["Popularity"].mean().reset_index()
    top_artists = avg_popularity.nlargest(5, "Popularity")["Artist"]

    # 🔹 Step 6: Find the most popular

# %% [markdown]
# Q8. Visualize relationships between multiple numerical variables simultaneously using a pair plot.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files

# Upload the file manually
uploaded = files.upload()

# Get the correct filename dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
df = pd.read_csv(file_name)

# Select relevant numerical columns for visualization
num_columns = ["Popularity", "Duration (ms)"]  # Add more numerical columns as needed

# Create the pair plot
sns.pairplot(df[num_columns])
plt.show()

# %% [markdown]
# Q9. Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files

# Upload the file manually
uploaded = files.upload()

# Get the correct filename dynamically
file_name = list(uploaded.keys())[0]

# Load the dataset
df = pd.read_csv(file_name)

# Filter top artists for better readability
top_artists = df["Artist"].value_counts().head(10).index
df_filtered = df[df["Artist"].isin(top_artists)]

# Plot box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x="Artist", y="Duration (ms)", data=df_filtered)
plt.xticks(rotation=45)
plt.title("Distribution of Track Durations by Artist (Box Plot)")
plt.show()

# Plot violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(x="Artist", y="Duration (ms)", data=df_filtered)
plt.xticks(rotation=45)
plt.title("Distribution of Track Durations by Artist (Violin Plot)")
plt.show()

# %% [markdown]
# Q10. How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a vilon plot?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = "/content/spotify.csv"  # Update this path if needed
df = pd.read_csv(file_path)

# Set figure size
plt.figure(figsize=(12, 6))

# Swarm plot
sns.swarmplot(x="Artist", y="Popularity", data=df, size=4)

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Title and labels
plt.title("Distribution of Track Popularity by Artist")
plt.xlabel("Artist")
plt.ylabel("Popularity")

# Show plot
plt.show()
